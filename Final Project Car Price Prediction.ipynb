# %%
import numpy as np
import pandas as pd
# Out:
# C:\Users\Shuba\AppData\Local\Temp\ipykernel_23568\1662815981.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Shuba\Downloads\Cardetails.csv")

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
df.shape
# Out:
# (8128, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
df.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage          0
# engine           0
# max_power        0
# torque           0
# seats            0
# dtype: int64

# %%
df.shape
# Out:
# (7906, 13)

# %%
df.duplicated().sum()
# Out:
# 1189

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (6717, 13)

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
np.round(df.describe())
# Out:
#          year  selling_price  km_driven   seats
# count  6717.0         6717.0     6717.0  6717.0
# mean   2014.0       526386.0    73398.0     5.0
# std       4.0       523550.0    58703.0     1.0
# min    1994.0        29999.0        1.0     2.0
# 25%    2011.0       250000.0    38000.0     5.0
# 50%    2014.0       420000.0    68203.0     5.0
# 75%    2017.0       650000.0   100000.0     5.0
# max    2020.0     10000000.0  2360457.0    14.0

# %%
def get_brand_name(car_name):
    car_name= car_name.split(' ')[0]
    return car_name.strip()

# %%
df["name"]= df["name"].apply(get_brand_name)

# %%
df
# Out:
#          name  year  selling_price  km_driven    fuel seller_type  \
# 0      Maruti  2014         450000     145500  Diesel  Individual
# 1       Skoda  2014         370000     120000  Diesel  Individual
# 2       Honda  2006         158000     140000  Petrol  Individual
# 3     Hyundai  2010         225000     127000  Diesel  Individual
# 4      Maruti  2007         130000     120000  Petrol  Individual
# ...       ...   ...            ...        ...     ...         ...
# 8121   Maruti  2013         260000      50000  Petrol  Individual
# 8122  Hyundai  2014         475000      80000  Diesel  Individual
# 8123  Hyundai  2013         320000     110000  Petrol  Individual
# 8124  Hyundai  2007         135000     119000  Diesel  Individual
# 8125   Maruti  2009         382000     120000  Diesel  Individual
#
#      transmission                 owner     mileage   engine   max_power  \
# 0          Manual           First Owner   23.4 kmpl  1248 CC      74 bhp
# ...

# %%
df["fuel"].unique()
# Out:
# array(['Diesel', 'Petrol', 'LPG', 'CNG'], dtype=object)

# %%
df["fuel"]= df["fuel"].map({'Diesel':1, 'Petrol':2, 'LPG':3, 'CNG':4})

# %%
df.head()
# Out:
#       name  year  selling_price  km_driven  fuel seller_type transmission  \
# 0   Maruti  2014         450000     145500     1  Individual       Manual
# 1    Skoda  2014         370000     120000     1  Individual       Manual
# 2    Honda  2006         158000     140000     2  Individual       Manual
# 3  Hyundai  2010         225000     127000     1  Individual       Manual
# 4   Maruti  2007         130000     120000     2  Individual       Manual
#
#           owner     mileage   engine   max_power                    torque  \
# 0   First Owner   23.4 kmpl  1248 CC      74 bhp            190Nm@ 2000rpm
# 1  Second Owner  21.14 kmpl  1498 CC  103.52 bhp       250Nm@ 1500-2500rpm
# 2   Third Owner   17.7 kmpl  1497 CC      78 bhp     12.7@ 2,700(kgm@ rpm)
# 3   First Owner   23.0 kmpl  1396 CC      90 bhp  22.4 kgm at 1750-2750rpm
# 4   First Owner   16.1 kmpl  1298 CC    88.2 bhp     11.5@ 4,500(kgm@ rpm)
#
#    seats
# 0    5.0
# 1    5.0
# 2    5.0
# 3    5.0
# 4    5.0

# %%
df["seller_type"].unique()
# Out:
# array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object)

# %%
df["seller_type"] = df["seller_type"].map({'Individual':1, 'Dealer':2, 'Trustmark Dealer':3})

# %%
df.head()
# Out:
#       name  year  selling_price  km_driven  fuel  seller_type transmission  \
# 0   Maruti  2014         450000     145500     1            1       Manual
# 1    Skoda  2014         370000     120000     1            1       Manual
# 2    Honda  2006         158000     140000     2            1       Manual
# 3  Hyundai  2010         225000     127000     1            1       Manual
# 4   Maruti  2007         130000     120000     2            1       Manual
#
#           owner     mileage   engine   max_power                    torque  \
# 0   First Owner   23.4 kmpl  1248 CC      74 bhp            190Nm@ 2000rpm
# 1  Second Owner  21.14 kmpl  1498 CC  103.52 bhp       250Nm@ 1500-2500rpm
# 2   Third Owner   17.7 kmpl  1497 CC      78 bhp     12.7@ 2,700(kgm@ rpm)
# 3   First Owner   23.0 kmpl  1396 CC      90 bhp  22.4 kgm at 1750-2750rpm
# 4   First Owner   16.1 kmpl  1298 CC    88.2 bhp     11.5@ 4,500(kgm@ rpm)
#
#    seats
# 0    5.0
# 1    5.0
# 2    5.0
# 3    5.0
# 4    5.0

# %%
df["transmission"].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
df["transmission"] = df["transmission"].map({'Manual':1, 'Automatic':2})

# %%
df.head()
# Out:
#       name  year  selling_price  km_driven  fuel  seller_type  transmission  \
# 0   Maruti  2014         450000     145500     1            1             1
# 1    Skoda  2014         370000     120000     1            1             1
# 2    Honda  2006         158000     140000     2            1             1
# 3  Hyundai  2010         225000     127000     1            1             1
# 4   Maruti  2007         130000     120000     2            1             1
#
#           owner     mileage   engine   max_power                    torque  \
# 0   First Owner   23.4 kmpl  1248 CC      74 bhp            190Nm@ 2000rpm
# 1  Second Owner  21.14 kmpl  1498 CC  103.52 bhp       250Nm@ 1500-2500rpm
# 2   Third Owner   17.7 kmpl  1497 CC      78 bhp     12.7@ 2,700(kgm@ rpm)
# 3   First Owner   23.0 kmpl  1396 CC      90 bhp  22.4 kgm at 1750-2750rpm
# 4   First Owner   16.1 kmpl  1298 CC    88.2 bhp     11.5@ 4,500(kgm@ rpm)
#
#    seats
# 0    5.0
# 1    5.0
# 2    5.0
# 3    5.0
# ...

# %%
df["owner"].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner',
#        'Fourth & Above Owner', 'Test Drive Car'], dtype=object)

# %%
df["owner"] = df["owner"].map({'First Owner':1, 'Second Owner':2, 'Third Owner':3,
       'Fourth & Above Owner':4, 'Test Drive Car':5})

# %%
df.head()
# Out:
#       name  year  selling_price  km_driven  fuel  seller_type  transmission  \
# 0   Maruti  2014         450000     145500     1            1             1
# 1    Skoda  2014         370000     120000     1            1             1
# 2    Honda  2006         158000     140000     2            1             1
# 3  Hyundai  2010         225000     127000     1            1             1
# 4   Maruti  2007         130000     120000     2            1             1
#
#    owner     mileage   engine   max_power                    torque  seats
# 0      1   23.4 kmpl  1248 CC      74 bhp            190Nm@ 2000rpm    5.0
# 1      2  21.14 kmpl  1498 CC  103.52 bhp       250Nm@ 1500-2500rpm    5.0
# 2      3   17.7 kmpl  1497 CC      78 bhp     12.7@ 2,700(kgm@ rpm)    5.0
# 3      1   23.0 kmpl  1396 CC      90 bhp  22.4 kgm at 1750-2750rpm    5.0
# 4      1   16.1 kmpl  1298 CC    88.2 bhp     11.5@ 4,500(kgm@ rpm)    5.0

# %%
df["name"].unique()
# Out:
# array(['Maruti', 'Skoda', 'Honda', 'Hyundai', 'Toyota', 'Ford', 'Renault',
#        'Mahindra', 'Tata', 'Chevrolet', 'Datsun', 'Jeep', 'Mercedes-Benz',
#        'Mitsubishi', 'Audi', 'Volkswagen', 'BMW', 'Nissan', 'Lexus',
#        'Jaguar', 'Land', 'MG', 'Volvo', 'Daewoo', 'Kia', 'Fiat', 'Force',
#        'Ambassador', 'Ashok', 'Isuzu', 'Opel'], dtype=object)

# %%
df["name"] = df["name"].map({'Maruti':1, 'Skoda':2, 'Honda':3, 'Hyundai':4, 'Toyota':5, 'Ford':6, 'Renault':7,
       'Mahindra':8, 'Tata':9, 'Chevrolet':10, 'Datsun':11, 'Jeep':12, 'Mercedes-Benz':13,
       'Mitsubishi':14, 'Audi':15, 'Volkswagen':16, 'BMW':17, 'Nissan':18, 'Lexus':19,
       'Jaguar':20, 'Land':21, 'MG':22, 'Volvo':23, 'Daewoo':24, 'Kia':25, 'Fiat':26, 'Force':27,
       'Ambassador':28, 'Ashok':29, 'Isuzu':30, 'Opel':31})

# %%
def clean_data(value):
    value=value.split(' ')[0]
    value= value.strip()
    if value=='':
        value=0
    return float(value)

# %%
df["mileage"]= df["mileage"].apply(clean_data)

# %%
df["mileage"]
# Out:
# 0       23.40
# 1       21.14
# 2       17.70
# 3       23.00
# 4       16.10
#         ...
# 8121    18.90
# 8122    22.54
# 8123    18.50
# 8124    16.80
# 8125    19.30
# Name: mileage, Length: 6717, dtype: float64

# %%
df
# Out:
#       name  year  selling_price  km_driven  fuel  seller_type  transmission  \
# 0        1  2014         450000     145500     1            1             1
# 1        2  2014         370000     120000     1            1             1
# 2        3  2006         158000     140000     2            1             1
# 3        4  2010         225000     127000     1            1             1
# 4        1  2007         130000     120000     2            1             1
# ...    ...   ...            ...        ...   ...          ...           ...
# 8121     1  2013         260000      50000     2            1             1
# 8122     4  2014         475000      80000     1            1             1
# 8123     4  2013         320000     110000     2            1             1
# 8124     4  2007         135000     119000     1            1             1
# 8125     1  2009         382000     120000     1            1             1
#
# ...

# %%
df["engine"]= df["engine"].apply(clean_data)

# %%
df["max_power"]= df["max_power"].apply(clean_data)

# %%
df
# Out:
#       name  year  selling_price  km_driven  fuel  seller_type  transmission  \
# 0        1  2014         450000     145500     1            1             1
# 1        2  2014         370000     120000     1            1             1
# 2        3  2006         158000     140000     2            1             1
# 3        4  2010         225000     127000     1            1             1
# 4        1  2007         130000     120000     2            1             1
# ...    ...   ...            ...        ...   ...          ...           ...
# 8121     1  2013         260000      50000     2            1             1
# 8122     4  2014         475000      80000     1            1             1
# 8123     4  2013         320000     110000     2            1             1
# 8124     4  2007         135000     119000     1            1             1
# 8125     1  2009         382000     120000     1            1             1
#
# ...

# %%
df.drop(["torque"],axis=1,inplace=True)

# %%
df.head()
# Out:
#    name  year  selling_price  km_driven  fuel  seller_type  transmission  \
# 0     1  2014         450000     145500     1            1             1
# 1     2  2014         370000     120000     1            1             1
# 2     3  2006         158000     140000     2            1             1
# 3     4  2010         225000     127000     1            1             1
# 4     1  2007         130000     120000     2            1             1
#
#    owner  mileage  engine  max_power  seats
# 0      1    23.40  1248.0      74.00    5.0
# 1      2    21.14  1498.0     103.52    5.0
# 2      3    17.70  1497.0      78.00    5.0
# 3      1    23.00  1396.0      90.00    5.0
# 4      1    16.10  1298.0      88.20    5.0

# %%
df = df[df["year"]>=2002]

# %%
df["selling_price"].plot.box()
# Out:
# <Axes: >

# %%
df = df[df["selling_price"]<=df["selling_price"].quantile(0.94)]

# %%
df["km_driven"].plot.box()
# Out:
# <Axes: >

# %%
df = df[df["km_driven"]<=df["km_driven"].quantile(0.97)]

# %%
df.head()
# Out:
#    name  year  selling_price  km_driven  fuel  seller_type  transmission  \
# 0     1  2014         450000     145500     1            1             1
# 1     2  2014         370000     120000     1            1             1
# 2     3  2006         158000     140000     2            1             1
# 3     4  2010         225000     127000     1            1             1
# 4     1  2007         130000     120000     2            1             1
#
#    owner  mileage  engine  max_power  seats
# 0      1    23.40  1248.0      74.00    5.0
# 1      2    21.14  1498.0     103.52    5.0
# 2      3    17.70  1497.0      78.00    5.0
# 3      1    23.00  1396.0      90.00    5.0
# 4      1    16.10  1298.0      88.20    5.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6092 entries, 0 to 8125
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           6092 non-null   int64
#  1   year           6092 non-null   int64
#  2   selling_price  6092 non-null   int64
#  3   km_driven      6092 non-null   int64
#  4   fuel           6092 non-null   int64
#  5   seller_type    6092 non-null   int64
#  6   transmission   6092 non-null   int64
#  7   owner          6092 non-null   int64
#  8   mileage        6092 non-null   float64
#  9   engine         6092 non-null   float64
#  10  max_power      6092 non-null   float64
#  11  seats          6092 non-null   float64
# dtypes: float64(4), int64(8)
# memory usage: 618.7 KB

# %%
df.reset_index(inplace=True)

# %%
df.drop(["index"],axis=1,inplace=True)

# %%
df
# Out:
#       name  year  selling_price  km_driven  fuel  seller_type  transmission  \
# 0        1  2014         450000     145500     1            1             1
# 1        2  2014         370000     120000     1            1             1
# 2        3  2006         158000     140000     2            1             1
# 3        4  2010         225000     127000     1            1             1
# 4        1  2007         130000     120000     2            1             1
# ...    ...   ...            ...        ...   ...          ...           ...
# 6087     1  2013         260000      50000     2            1             1
# 6088     4  2014         475000      80000     1            1             1
# 6089     4  2013         320000     110000     2            1             1
# 6090     4  2007         135000     119000     1            1             1
# 6091     1  2009         382000     120000     1            1             1
#
#       owner  mileage  engine  max_power  seats
# ...

# %%
np.round(df.describe())
# Out:
#          name    year  selling_price  km_driven    fuel  seller_type  \
# count  6092.0  6092.0         6092.0     6092.0  6092.0       6092.0
# mean      5.0  2014.0       438405.0    69349.0     2.0          1.0
# std       4.0     4.0       238582.0    38943.0     1.0          0.0
# min       1.0  2002.0        31504.0        1.0     1.0          1.0
# 25%       1.0  2011.0       250000.0    39409.0     1.0          1.0
# 50%       4.0  2014.0       400000.0    68222.0     1.0          1.0
# 75%       8.0  2017.0       600000.0   100000.0     2.0          1.0
# max      28.0  2020.0      1100000.0   185000.0     4.0          3.0
#
#        transmission   owner  mileage  engine  max_power   seats
# count        6092.0  6092.0   6092.0  6092.0     6092.0  6092.0
# mean            1.0     1.0     20.0  1372.0       83.0     5.0
# std             0.0     1.0      4.0   440.0       25.0     1.0
# min             1.0     1.0      0.0   624.0       33.0     2.0
# ...

# %%
X=df.drop(["selling_price"],axis=1)

# %%
X
# Out:
#       name  year  km_driven  fuel  seller_type  transmission  owner  mileage  \
# 0        1  2014     145500     1            1             1      1    23.40
# 1        2  2014     120000     1            1             1      2    21.14
# 2        3  2006     140000     2            1             1      3    17.70
# 3        4  2010     127000     1            1             1      1    23.00
# 4        1  2007     120000     2            1             1      1    16.10
# ...    ...   ...        ...   ...          ...           ...    ...      ...
# 8121     1  2013      50000     2            1             1      2    18.90
# 8122     4  2014      80000     1            1             1      2    22.54
# 8123     4  2013     110000     2            1             1      1    18.50
# 8124     4  2007     119000     1            1             1      4    16.80
# 8125     1  2009     120000     1            1             1      1    19.30
#
#       engine  max_power  seats
# ...

# %%
y=df["selling_price"]

# %%
y
# Out:
# 0       450000
# 1       370000
# 2       158000
# 3       225000
# 4       130000
#          ...
# 6087    260000
# 6088    475000
# 6089    320000
# 6090    135000
# 6091    382000
# Name: selling_price, Length: 6092, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
X_tr,X_te,y_tr,y_te=train_test_split(X,y,test_size=0.20,random_state=45)

# %%
lr=LinearRegression()
dt=DecisionTreeRegressor()
rf=RandomForestRegressor()

# %%
lr.fit(X_tr,y_tr)
dt.fit(X_tr,y_tr)
rf.fit(X_tr,y_tr)
# Out:
# RandomForestRegressor()

# %%
y_pred1=lr.predict(X_te)
y_pred2=dt.predict(X_te)
y_pred3=rf.predict(X_te)

# %%
score1 = r2_score(y_te,y_pred1)

# %%
score1
# Out:
# 0.746850149883646

# %%
score2 = r2_score(y_te,y_pred2)

# %%
score2
# Out:
# 0.7981264113254758

# %%
score3 = r2_score(y_te,y_pred3)

# %%
score3
# Out:
# 0.8804741352825861

# %%
input_data_model = pd.DataFrame(
    [[5,2023,1200,1,1,1,2,12.99,2494.0,100.6,5.0]],
    columns=["name","year","km_driven","fuel","seller_type","transmission","owner","mileage","engine","max_power","seats"])

# %%
input_data_model
# Out:
#    name  year  km_driven  fuel  seller_type  transmission  owner  mileage  \
# 0     5  2023       1200     1            1             1      2    12.99
#
#    engine  max_power  seats
# 0  2494.0      100.6    5.0

# %%
rf.predict(input_data_model)
# Out:
# array([834379.98])
