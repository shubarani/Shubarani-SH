# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

df = pd.read_csv(r"C:\Users\Shuba\Downloads\CarsData.csv")

# %%
df["price"] = np.round(df["price"]*90.23, decimals=0)

# %%
df["price"] = df["price"].astype(int)

# %%
df["kmpl"]= np.round((df["mpg"]*1.6093)/3.78541,decimals=2)

# %%
df.head()
# Out:
#            model  year    price transmission  mileage fuelType  tax   mpg  \
# 0            I10  2017   676274       Manual    11630   Petrol  145  60.1
# 1           Polo  2017   991537       Manual     9200   Petrol  145  58.9
# 2       2 Series  2019  2525538    Semi-Auto     1614   Diesel  145  49.6
# 3   Yeti Outdoor  2017  1127424       Manual    30960   Diesel  150  62.8
# 4         Fiesta  2017   721750       Manual    19353   Petrol  125  54.3
#
#    engineSize Manufacturer   kmpl
# 0         1.0       hyundi  25.55
# 1         1.0   volkswagen  25.04
# 2         2.0          BMW  21.09
# 3         2.0        skoda  26.70
# 4         1.2         ford  23.08

# %%
df.drop("mpg" , axis=1, inplace=True)

# %%
df.head()
# Out:
#            model  year    price transmission  mileage fuelType  tax  \
# 0            I10  2017   676274       Manual    11630   Petrol  145
# 1           Polo  2017   991537       Manual     9200   Petrol  145
# 2       2 Series  2019  2525538    Semi-Auto     1614   Diesel  145
# 3   Yeti Outdoor  2017  1127424       Manual    30960   Diesel  150
# 4         Fiesta  2017   721750       Manual    19353   Petrol  125
#
#    engineSize Manufacturer   kmpl
# 0         1.0       hyundi  25.55
# 1         1.0   volkswagen  25.04
# 2         2.0          BMW  21.09
# 3         2.0        skoda  26.70
# 4         1.2         ford  23.08

# %%
df.drop("mileage", axis=1, inplace=True)

# %%
df.head()
# Out:
#            model  year    price transmission fuelType  tax  engineSize  \
# 0            I10  2017   676274       Manual   Petrol  145         1.0
# 1           Polo  2017   991537       Manual   Petrol  145         1.0
# 2       2 Series  2019  2525538    Semi-Auto   Diesel  145         2.0
# 3   Yeti Outdoor  2017  1127424       Manual   Diesel  150         2.0
# 4         Fiesta  2017   721750       Manual   Petrol  125         1.2
#
#   Manufacturer   kmpl
# 0       hyundi  25.55
# 1   volkswagen  25.04
# 2          BMW  21.09
# 3        skoda  26.70
# 4         ford  23.08

# %%
df["model"].value_counts()
# Out:
# model
#  Fiesta     6509
#  Golf       4797
#  Focus      4555
#  C Class    3694
#  Corsa      3285
#             ...
# E Class        1
# 200            1
#  Ranger        1
# 180            1
# 220            1
# Name: count, Length: 196, dtype: int64

# %%
df["Manufacturer"].value_counts()
# Out:
# Manufacturer
# ford          17811
# volkswagen    14893
# vauxhall      13258
# merc          12860
# BMW           10664
# Audi          10565
# toyota         6699
# skoda          6188
# hyundi         4774
# Name: count, dtype: int64

# %%
df[df["Manufacturer"]=="merc"]
# Out:
#             model  year    price transmission fuelType  tax  engineSize  \
# 9         A Class  2017  1578845       Manual   Diesel   30         2.1
# 17      GLA Class  2016  1407588    Automatic   Diesel   30         2.1
# 32        C Class  2015  1509728    Automatic   Diesel   30         2.1
# 49        C Class  2019  2606474    Automatic   Diesel  145         2.0
# 50      GLC Class  2018  1881296    Automatic   Diesel  150         2.1
# ...           ...   ...      ...          ...      ...  ...         ...
# 97654     C Class  2017  1775726    Semi-Auto   Diesel   30         2.1
# 97655   CLA Class  2016  1244723    Automatic   Diesel   20         2.1
# 97666     A Class  2016  1316456       Manual   Diesel   20         1.5
# 97668    CL Class  2017  1710400    Semi-Auto   Diesel   20         2.1
# 97669     C Class  2015  1326201    Semi-Auto   Petrol  125         2.0
#
#       Manufacturer   kmpl
# 9             merc  26.70
# 17            merc  27.29
# ...

# %%
df["fuelType"].value_counts()
# Out:
# fuelType
# Petrol      53982
# Diesel      40419
# Hybrid       3059
# Other         246
# Electric        6
# Name: count, dtype: int64

# %%
df["transmission"].value_counts()
# Out:
# transmission
# Manual       55502
# Semi-Auto    22296
# Automatic    19905
# Other            9
# Name: count, dtype: int64

# %%
df[df["fuelType"]!="Other"]
df["fuelType"]
df[df["transmission"]!="Other"]
# Out:
#                model  year    price transmission fuelType  tax  engineSize  \
# 0                I10  2017   676274       Manual   Petrol  145         1.0
# 1               Polo  2017   991537       Manual   Petrol  145         1.0
# 2           2 Series  2019  2525538    Semi-Auto   Diesel  145         2.0
# 3       Yeti Outdoor  2017  1127424       Manual   Diesel  150         2.0
# 4             Fiesta  2017   721750       Manual   Petrol  125         1.2
# ...              ...   ...      ...          ...      ...  ...         ...
# 97707         Fiesta  2017   942633    Automatic   Petrol  145         1.0
# 97708       3 Series  2014  1352999       Manual   Diesel   30         2.0
# 97709         Fiesta  2017   807558       Manual   Petrol  125         1.2
# 97710          Astra  2017   965461    Automatic   Petrol  125         1.4
# 97711    Grandland X  2019  1425454       Manual   Diesel  150         1.5
#
#       Manufacturer   kmpl
# 0           hyundi  25.55
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97712 entries, 0 to 97711
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         97712 non-null  object
#  1   year          97712 non-null  int64
#  2   price         97712 non-null  int32
#  3   transmission  97712 non-null  object
#  4   fuelType      97712 non-null  object
#  5   tax           97712 non-null  int64
#  6   engineSize    97712 non-null  float64
#  7   Manufacturer  97712 non-null  object
#  8   kmpl          97712 non-null  float64
# dtypes: float64(2), int32(1), int64(2), object(4)
# memory usage: 6.3+ MB

# %%
df[(df[["year"]>2010)&(df["year"]<2021)]
# Out:
#   Cell In[57], line 1
#     df[(df[["year"]>2010)&(df["year"]<2021)]
#                         ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
df[(df["year"]>2010)&(df["year"]<2020)]
# Out:
#                model  year    price transmission fuelType  tax  engineSize  \
# 0                I10  2017   676274       Manual   Petrol  145         1.0
# 1               Polo  2017   991537       Manual   Petrol  145         1.0
# 2           2 Series  2019  2525538    Semi-Auto   Diesel  145         2.0
# 3       Yeti Outdoor  2017  1127424       Manual   Diesel  150         2.0
# 4             Fiesta  2017   721750       Manual   Petrol  125         1.2
# ...              ...   ...      ...          ...      ...  ...         ...
# 97707         Fiesta  2017   942633    Automatic   Petrol  145         1.0
# 97708       3 Series  2014  1352999       Manual   Diesel   30         2.0
# 97709         Fiesta  2017   807558       Manual   Petrol  125         1.2
# 97710          Astra  2017   965461    Automatic   Petrol  125         1.4
# 97711    Grandland X  2019  1425454       Manual   Diesel  150         1.5
#
#       Manufacturer   kmpl
# 0           hyundi  25.55
# ...

# %%
df[(df["year"]>2010)&(df["year"]<2021)]
# Out:
#                model  year    price transmission fuelType  tax  engineSize  \
# 0                I10  2017   676274       Manual   Petrol  145         1.0
# 1               Polo  2017   991537       Manual   Petrol  145         1.0
# 2           2 Series  2019  2525538    Semi-Auto   Diesel  145         2.0
# 3       Yeti Outdoor  2017  1127424       Manual   Diesel  150         2.0
# 4             Fiesta  2017   721750       Manual   Petrol  125         1.2
# ...              ...   ...      ...          ...      ...  ...         ...
# 97707         Fiesta  2017   942633    Automatic   Petrol  145         1.0
# 97708       3 Series  2014  1352999       Manual   Diesel   30         2.0
# 97709         Fiesta  2017   807558       Manual   Petrol  125         1.2
# 97710          Astra  2017   965461    Automatic   Petrol  125         1.4
# 97711    Grandland X  2019  1425454       Manual   Diesel  150         1.5
#
#       Manufacturer   kmpl
# 0           hyundi  25.55
# ...

# %%
df[(df["year"]>2010)&(df["year"]<2020)]
# Out:
#                model  year    price transmission fuelType  tax  engineSize  \
# 0                I10  2017   676274       Manual   Petrol  145         1.0
# 1               Polo  2017   991537       Manual   Petrol  145         1.0
# 2           2 Series  2019  2525538    Semi-Auto   Diesel  145         2.0
# 3       Yeti Outdoor  2017  1127424       Manual   Diesel  150         2.0
# 4             Fiesta  2017   721750       Manual   Petrol  125         1.2
# ...              ...   ...      ...          ...      ...  ...         ...
# 97707         Fiesta  2017   942633    Automatic   Petrol  145         1.0
# 97708       3 Series  2014  1352999       Manual   Diesel   30         2.0
# 97709         Fiesta  2017   807558       Manual   Petrol  125         1.2
# 97710          Astra  2017   965461    Automatic   Petrol  125         1.4
# 97711    Grandland X  2019  1425454       Manual   Diesel  150         1.5
#
#       Manufacturer   kmpl
# 0           hyundi  25.55
# ...

# %%
df
# Out:
#                model  year    price transmission fuelType  tax  engineSize  \
# 0                I10  2017   676274       Manual   Petrol  145         1.0
# 1               Polo  2017   991537       Manual   Petrol  145         1.0
# 2           2 Series  2019  2525538    Semi-Auto   Diesel  145         2.0
# 3       Yeti Outdoor  2017  1127424       Manual   Diesel  150         2.0
# 4             Fiesta  2017   721750       Manual   Petrol  125         1.2
# ...              ...   ...      ...          ...      ...  ...         ...
# 97707         Fiesta  2017   942633    Automatic   Petrol  145         1.0
# 97708       3 Series  2014  1352999       Manual   Diesel   30         2.0
# 97709         Fiesta  2017   807558       Manual   Petrol  125         1.2
# 97710          Astra  2017   965461    Automatic   Petrol  125         1.4
# 97711    Grandland X  2019  1425454       Manual   Diesel  150         1.5
#
#       Manufacturer   kmpl
# 0           hyundi  25.55
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97712 entries, 0 to 97711
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         97712 non-null  object
#  1   year          97712 non-null  int64
#  2   price         97712 non-null  int32
#  3   transmission  97712 non-null  object
#  4   fuelType      97712 non-null  object
#  5   tax           97712 non-null  int64
#  6   engineSize    97712 non-null  float64
#  7   Manufacturer  97712 non-null  object
#  8   kmpl          97712 non-null  float64
# dtypes: float64(2), int32(1), int64(2), object(4)
# memory usage: 6.3+ MB

# %%
df = pd.read_excel(r"C:\Users\Shuba\Downloads\Cars.xlsx")

# %%
df.head()
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 0            I10  2017   7495       Manual    11630   Petrol  145  60.1
# 1           Polo  2017  10989       Manual     9200   Petrol  145  58.9
# 2       2 Series  2019  27990    Semi-Auto     1614   Diesel  145  49.6
# 3   Yeti Outdoor  2017  12495       Manual    30960   Diesel  150  62.8
# 4         Fiesta  2017   7999       Manual    19353   Petrol  125  54.3
#
#    engineSize Manufacturer
# 0         1.0       hyundi
# 1         1.0   volkswagen
# 2         2.0          BMW
# 3         2.0        skoda
# 4         1.2         ford

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         5 non-null      object
#  1   year          5 non-null      int64
#  2   price         5 non-null      int64
#  3   transmission  5 non-null      object
#  4   mileage       5 non-null      int64
#  5   fuelType      5 non-null      object
#  6   tax           5 non-null      int64
#  7   mpg           5 non-null      float64
#  8   engineSize    5 non-null      float64
#  9   Manufacturer  5 non-null      object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 532.0+ bytes

# %%
df["price"]=df["price"]*82.89

# %% [markdown]
# # miles to km = miles * 1.6093
#
# # Gallons to liter = gallons *3.78541
#
# # Need to convert mpg to Kmpl

# %%
df["kmpl"]= (df["mpg"]*1.6093)/3.78541

# %%
df.drop("Kmpl", axis=1, inplace=True)

# %%
df.drop("mpg", axis=1,inplace=True)

# %%
df["kmpl"]  = np.round(df["kmpl"], decimals=2)

# %%
df.drop("mileage", axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         5 non-null      object
#  1   year          5 non-null      int64
#  2   price         5 non-null      float64
#  3   transmission  5 non-null      object
#  4   fuelType      5 non-null      object
#  5   tax           5 non-null      int64
#  6   engineSize    5 non-null      float64
#  7   Manufacturer  5 non-null      object
#  8   kmpl          5 non-null      float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 492.0+ bytes

# %%
df["transmission"]
# Out:
# 0       Manual
# 1       Manual
# 2    Semi-Auto
# 3       Manual
# 4       Manual
# Name: transmission, dtype: object

# %%
df["fuelType"]
# Out:
# 0    Petrol
# 1    Petrol
# 2    Diesel
# 3    Diesel
# 4    Petrol
# Name: fuelType, dtype: object

# %%
df["Manufacturer"]
# Out:
# 0        hyundi
# 1    volkswagen
# 2           BMW
# 3         skoda
# 4          ford
# Name: Manufacturer, dtype: object

# %%
df [df["Manufacturer"] =="BMW"]
# Out:
#        model  year      price transmission fuelType  tax  engineSize  \
# 2   2 Series  2019  2320091.1    Semi-Auto   Diesel  145         2.0
#
#   Manufacturer   kmpl
# 2          BMW  21.09

# %%
df["model"].value_counts()
# Out:
# model
# I10             1
# Polo            1
# 2 Series        1
# Yeti Outdoor    1
# Fiesta          1
# Name: count, dtype: int64

# %%
df[df["fuelType"]=="Diesel"]
# Out:
#            model  year       price transmission fuelType  tax  engineSize  \
# 2       2 Series  2019  2320091.10    Semi-Auto   Diesel  145         2.0
# 3   Yeti Outdoor  2017  1035710.55       Manual   Diesel  150         2.0
#
#   Manufacturer   kmpl
# 2          BMW  21.09
# 3        skoda  26.70

# %%
df
# Out:
#            model  year       price transmission fuelType  tax  engineSize  \
# 0            I10  2017   621260.55       Manual   Petrol  145         1.0
# 1           Polo  2017   910878.21       Manual   Petrol  145         1.0
# 2       2 Series  2019  2320091.10    Semi-Auto   Diesel  145         2.0
# 3   Yeti Outdoor  2017  1035710.55       Manual   Diesel  150         2.0
# 4         Fiesta  2017   663037.11       Manual   Petrol  125         1.2
#
#   Manufacturer   kmpl
# 0       hyundi  25.55
# 1   volkswagen  25.04
# 2          BMW  21.09
# 3        skoda  26.70
# 4         ford  23.08

# %%
df.loc[1:4]
# Out:
#            model  year       price transmission fuelType  tax  engineSize  \
# 1           Polo  2017   910878.21       Manual   Petrol  145         1.0
# 2       2 Series  2019  2320091.10    Semi-Auto   Diesel  145         2.0
# 3   Yeti Outdoor  2017  1035710.55       Manual   Diesel  150         2.0
# 4         Fiesta  2017   663037.11       Manual   Petrol  125         1.2
#
#   Manufacturer   kmpl
# 1   volkswagen  25.04
# 2          BMW  21.09
# 3        skoda  26.70
# 4         ford  23.08

# %%
df["year"].value_counts()
# Out:
# year
# 2017    4
# 2019    1
# Name: count, dtype: int64

# %%
df[(df["year"]>2010)&(df["year"]<2020)]
# Out:
#            model  year       price transmission fuelType  tax  engineSize  \
# 0            I10  2017   621260.55       Manual   Petrol  145         1.0
# 1           Polo  2017   910878.21       Manual   Petrol  145         1.0
# 2       2 Series  2019  2320091.10    Semi-Auto   Diesel  145         2.0
# 3   Yeti Outdoor  2017  1035710.55       Manual   Diesel  150         2.0
# 4         Fiesta  2017   663037.11       Manual   Petrol  125         1.2
#
#   Manufacturer   kmpl
# 0       hyundi  25.55
# 1   volkswagen  25.04
# 2          BMW  21.09
# 3        skoda  26.70
# 4         ford  23.08

# %%
df.head()
# Out:
#            model  year       price transmission fuelType  tax  engineSize  \
# 0            I10  2017   621260.55       Manual   Petrol  145         1.0
# 1           Polo  2017   910878.21       Manual   Petrol  145         1.0
# 2       2 Series  2019  2320091.10    Semi-Auto   Diesel  145         2.0
# 3   Yeti Outdoor  2017  1035710.55       Manual   Diesel  150         2.0
# 4         Fiesta  2017   663037.11       Manual   Petrol  125         1.2
#
#   Manufacturer   kmpl
# 0       hyundi  25.55
# 1   volkswagen  25.04
# 2          BMW  21.09
# 3        skoda  26.70
# 4         ford  23.08

# %%
np.round(df.groupby("model")["price"].mean().sort_values(ascending= False).head())
# Out:
# model
# 2 Series        2320091.0
# Yeti Outdoor    1035711.0
# Polo             910878.0
# Fiesta           663037.0
# I10              621261.0
# Name: price, dtype: float64

# %%
sns.barplot(np.round(df.groupby("model")["price"].mean().sort_values(ascending= False).head()))
# Out:
# <Axes: xlabel='model', ylabel='price'>

# %%
sns.barplot(np.round(df.groupby("model")["price"].mean().sort_values().head()))
# Out:
# <Axes: xlabel='model', ylabel='price'>

# %%
df.groupby("model")["kmpl"].mean().sort_values(ascending= False).head()
# Out:
# model
# Yeti Outdoor    26.70
# I10             25.55
# Polo            25.04
# Fiesta          23.08
# 2 Series        21.09
# Name: kmpl, dtype: float64

# %%
df.groupby(["model","fuelType"])["kmpl"].mean().sort_values(ascending=False)
# Out:
# model         fuelType
# Yeti Outdoor  Diesel      26.70
# I10           Petrol      25.55
# Polo          Petrol      25.04
# Fiesta        Petrol      23.08
# 2 Series      Diesel      21.09
# Name: kmpl, dtype: float64

# %%
pd.crosstab(df["transmission"],df["fuelType"])
# Out:
# fuelType      Diesel  Petrol
# transmission
# Manual             1       3
# Semi-Auto          1       0

# %%
df.groupby("fuelType")["price"].mean().sort_values(ascending=False)
# Out:
# fuelType
# Diesel    1677900.825
# Petrol     731725.290
# Name: price, dtype: float64

# %%
df[df["Manufacturer"]=="skoda"]
# Out:
#            model  year       price transmission fuelType  tax  engineSize  \
# 3   Yeti Outdoor  2017  1035710.55       Manual   Diesel  150         2.0
#
#   Manufacturer  kmpl
# 3        skoda  26.7

# %%
df[(df["year"]>2010)&(df["year"]<2020)]
# Out:
#            model  year       price transmission fuelType  tax  engineSize  \
# 0            I10  2017   621260.55       Manual   Petrol  145         1.0
# 1           Polo  2017   910878.21       Manual   Petrol  145         1.0
# 2       2 Series  2019  2320091.10    Semi-Auto   Diesel  145         2.0
# 3   Yeti Outdoor  2017  1035710.55       Manual   Diesel  150         2.0
# 4         Fiesta  2017   663037.11       Manual   Petrol  125         1.2
#
#   Manufacturer   kmpl
# 0       hyundi  25.55
# 1   volkswagen  25.04
# 2          BMW  21.09
# 3        skoda  26.70
# 4         ford  23.08

# %%
pd.crosstab(df["transmission"],df["fuelType"])
# Out:
# fuelType      Diesel  Petrol
# transmission
# Manual             1       3
# Semi-Auto          1       0

# %%
df[df["Manufacturer"]=="skoda"]
# Out:
#            model  year       price transmission fuelType  tax  engineSize  \
# 3   Yeti Outdoor  2017  1035710.55       Manual   Diesel  150         2.0
#
#   Manufacturer  kmpl
# 3        skoda  26.7

# %%
df.groupby("transmission")["price"].mean().sort_values(ascending=False)
# Out:
# transmission
# Semi-Auto    2320091.100
# Manual        807721.605
# Name: price, dtype: float64

# %%
pd.pivot_table(df,index="transmission",columns="fuelType",values="price",fill_value=0)
# Out:
# fuelType          Diesel     Petrol
# transmission
# Manual        1035710.55  731725.29
# Semi-Auto     2320091.10       0.00

# %%
pd.crosstab(df["transmission"],df["fuelType"])
# Out:
# fuelType      Diesel  Petrol
# transmission
# Manual             1       3
# Semi-Auto          1       0

# %%
df
# Out:
#            model  year       price transmission fuelType  tax  engineSize  \
# 0            I10  2017   621260.55       Manual   Petrol  145         1.0
# 1           Polo  2017   910878.21       Manual   Petrol  145         1.0
# 2       2 Series  2019  2320091.10    Semi-Auto   Diesel  145         2.0
# 3   Yeti Outdoor  2017  1035710.55       Manual   Diesel  150         2.0
# 4         Fiesta  2017   663037.11       Manual   Petrol  125         1.2
#
#   Manufacturer   kmpl
# 0       hyundi  25.55
# 1   volkswagen  25.04
# 2          BMW  21.09
# 3        skoda  26.70
# 4         ford  23.08

# %%
df[(df["year"]>2010)&(df["year"]<2020)]
# Out:
#            model  year       price transmission fuelType  tax  engineSize  \
# 0            I10  2017   621260.55       Manual   Petrol  145         1.0
# 1           Polo  2017   910878.21       Manual   Petrol  145         1.0
# 2       2 Series  2019  2320091.10    Semi-Auto   Diesel  145         2.0
# 3   Yeti Outdoor  2017  1035710.55       Manual   Diesel  150         2.0
# 4         Fiesta  2017   663037.11       Manual   Petrol  125         1.2
#
#   Manufacturer   kmpl
# 0       hyundi  25.55
# 1   volkswagen  25.04
# 2          BMW  21.09
# 3        skoda  26.70
# 4         ford  23.08

# %%
df[df["Manufacturer"]=="skoda"]
# Out:
#            model  year       price transmission fuelType  tax  engineSize  \
# 3   Yeti Outdoor  2017  1035710.55       Manual   Diesel  150         2.0
#
#   Manufacturer  kmpl
# 3        skoda  26.7

# %%
df.groupby("transmission")["price"].mean().sort_values(ascending=False)
# Out:
# transmission
# Semi-Auto    2320091.100
# Manual        807721.605
# Name: price, dtype: float64

# %%
pd.crosstab(df["transmission"],df["fuelType"])
# Out:
# fuelType      Diesel  Petrol
# transmission
# Manual             1       3
# Semi-Auto          1       0

# %%
pd.pivot_table(df,index="transmission",columns="fuelType",values="price",fill_value=0)
# Out:
# fuelType          Diesel     Petrol
# transmission
# Manual        1035710.55  731725.29
# Semi-Auto     2320091.10       0.00
