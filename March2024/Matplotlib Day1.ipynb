# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# C:\Users\Shuba\AppData\Local\Temp\ipykernel_18112\2080034654.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
np.random.seed(0)

# %%
data=pd.DataFrame({
    "A": np.random.randn(100),
    "B": np.random.rand(100)*100,
    "Category": np.random.choice(["X","Y","Z"],100)
})

# %%
data["Category"]
# Out:
# 0     Z
# 1     Z
# 2     X
# 3     Z
# 4     Z
#      ..
# 95    Z
# 96    Z
# 97    X
# 98    Z
# 99    X
# Name: Category, Length: 100, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 plt.plot(data["A"])
#
# TypeError: 'tuple' object is not callable

# %%
plt.plot(data["A"])

# %%
plt.scatter(data["A"],data["B"])
plt.title("Scatter Plot")
plt.xlabel("Values of A")
plt.ylabel("Values of B")
plt.show()

# %%
plt.bar(data["Category"],data["A"])
# Out:
# <BarContainer object of 100 artists>

# %%
plt.hist(data["A"])
# Out:
# (array([ 1.,  6., 14., 15., 24., 11., 13., 11.,  2.,  3.]),
#  array([-2.45653424, -1.95551449, -1.45449473, -0.95347498, -0.45245523,
#          0.04856453,  0.54958428,  1.05060404,  1.55162379,  2.05264355,
#          2.5536633 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot([1,2,3,4,5,15])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x270aa4fe720>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x270aa4fecc0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x270aa4fe450>],
#  'medians': [<matplotlib.lines.Line2D at 0x270aa4ff290>],
#  'fliers': [<matplotlib.lines.Line2D at 0x270aa4ff4d0>],
#  'means': []}

# %%
plt.joint(data["A"],data["B"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 plt.heatmap(data["A"],data["B"])
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'heatmap'

# %%
plt.pie(cat.values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 plt.pie(cat.values)
#
# NameError: name 'cat' is not defined

# %%
cat=data["Category"].value_counts()

# %%
cat.index
# Out:
# Index(['X', 'Y'], dtype='object', name='Category')

# %%
cat.values
# Out:
# array([71, 29], dtype=int64)

# %%
plt.pie(cat.values, labels=cat.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x270aa533f80>,
# ...
#  [Text(-0.6741977004263886, 0.8691705590617815, 'X'),
#   Text(0.6741976190487649, -0.8691706221847221, 'Y')])

# %%
new_data=np.linspace(-5,5,20).reshape(4,5)

# %%
plt.imshow(new_data)

# %%
plt.plot(data["A"])

# %%
plt.scatter(data["A"],data["B"])

# %%
plt.bar(data["Category"],data["A"])
# Out:
# <BarContainer object of 100 artists>

# %%
plt.hist(data["A"])
# Out:
# (array([ 2.,  3.,  7., 10., 15., 16., 14., 15., 12.,  6.]),
#  array([-2.80487822, -2.3388482 , -1.87281817, -1.40678815, -0.94075812,
#         -0.47472809, -0.00869807,  0.45733196,  0.92336198,  1.38939201,
#          1.85542203]),
#  <BarContainer object of 10 artists>)

# %%
cat=data["Category"].value_counts()

# %%
plt.pie(cat.values,labels=cat.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x270ad973770>,
# ...
#  [Text(0.46835717599151966, 0.995309778760989, 'X'),
#   Text(-1.0864571520991066, -0.1720780539542992, 'Z'),
#   Text(0.6182918791840069, -0.9097885205557991, 'Y')])

# %%
new_data=np.linspace(-5,5,20).reshape(4,5)
plt.imshow(new_data)
