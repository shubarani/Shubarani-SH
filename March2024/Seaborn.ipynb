# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
tips=pd.read_excel(r"C:\Users\Shuba\Downloads\tips.xlsx")

# %%
tips
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_style("darkgrid")
sns.scatterplot(data=tips,x="total_bill", y="tip", alpha=0.7)
plt.title("Total bill vs tips")
plt.show()

# %%
sns.histplot(data=tips, x="total_bill",kde=True,hue="gender")
plt
plt.show()

# %%
sns.barplot(data=tips,x="day",y="total_bill",hue="gender")
plt.title("Total bill by day and gender")
plt.show()

# %%
tips=pd.read_excel(r"C:\Users\Shuba\Downloads\tips.xlsx")

# %%
tips
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_style("darkgrid")
sns.scatterplot(data=tips, x= "total_bill", y="tip", alpha =0.7)
plt.title("Total bill vs Tips")
plt.show()

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip")
plt.show()

# %%
sns.lineplot(data=tips,x="total_bill",y="tip")
plt.show()

# %%
sns.histplot(data=tips, x="total_bill", kde=True, hue="gender")
plt.title("Total bill by gender")
plt.show()

# %%
sns.histplot(data=tips, x="total_bill", kde=True, hue="smoker")
plt.title("Total bill by smoker")
plt.show()

# %%
sns.barplot(data=tips, x='day',y="total_bill", hue='gender', estimator="mean")
plt.show()

# %%
sns.scatterplot(data=tips,x="total_bill", y="tip")
plt.show()

# %%
sns.lineplot(data=tips, x="total_bill",y="tip")
plt.show()

# %%
sns.histplot(data=tips, x="total_bill", kde=True, hue="gender")
plt.show()

# %%
sns.barplot(data=tips, x="day",y="total_bill", hue='gender')
plt.show()

# %%
sns.violinplot(data=tips,x="day", y="total_bill")
plt.show()

# %%
sns.boxplot(data=tips, y= "size")
plt.show()

# %%
sns.scatterplot(data=tips,x='total_bill',y='tip')
plt.show()

# %%
sns.lineplot(data=tips, x='total_bill',y="tip")
plt.show()

# %%
sns.histplot(data=tips,x="total_bill",kde=True,hue="gender")
plt.show()

# %%
sns.barplot(data=tips,x="day",y="total_bill",hue="gender")
plt.show()

# %%
sns.violinplot(data=tips,x="day", y="tip")
plt.show()

# %%
sns.violinplot(data=tips, x='day',y="total_bill")
plt.show()

# %%
sns.boxplot(data=tips,y="total_bill")
plt.show()

# %%
sns.jointplot(data=tips,x='total_bill',y="tip",kind="reg")
plt.show()

# %%
sns.countplot(data=tips,x="day",hue="gender")
plt.show()

# %%
sns.scatterplot(data=tips, x="total_bill",y="tip")
plt.show()

# %%
sns.lineplot(data=tips,x="total_bill",y="tip")
plt.show()

# %%
sns.histplot(data=tips,x="total_bill",kde=True,hue="gender")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.barplot(data=tips,x="day",y="total_bill",hue="gender")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=tips,y="tip")
# Out:
# <Axes: ylabel='tip'>

# %%
sns.jointplot(data=tips, x="tip",y="total_bill",kind="reg")
plt.show()

# %%
sns.countplot(data=tips,x="day",hue="gender")
plt.show()

# %%
sns.scatterplot(data=tips,x="total_bill",y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(data=tips,x="total_bill",y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.histplot(data=tips,x="total_bill",kde=True, hue="gender")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data=tips,x="total_bill",kde=True, hue="smoker")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.barplot(data=tips,x="day", y="tip", hue="gender")
plt.show()

# %%
sns.boxplot(data=tips,y="total_bill")
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.jointplot(data=tips,x="day",y="tip", kind="reg")
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 sns.jointplot(data=tips,x="day",y="tip", kind="reg")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:2326, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2323     grid.plot_marginals(histplot, **marginal_kws)
#    2325     joint_kws.setdefault("color", color)
# -> 2326     grid.plot_joint(regplot, **joint_kws)
#    2328 elif kind.startswith("resid"):
#    2330     joint_kws.setdefault("color", color)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:1832, in JointGrid.plot_joint(self, func, **kwargs)
#    1829     self._inject_kwargs(func, kwargs, self._hue_params)
# ...

# %%
sns.countplot(data=tips,x="day",hue="gender")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
tips=pd.read_excel(r"C:\Users\Shuba\Downloads\tips.xlsx")

# %%
sns.scatterplot(data=tips,x="total_bill",y="tip")
plt.title("Total_bill vs Tips")
plt.show()

# %%
sns.histplot(data=tips, x="total_bill",kde=True,hue="gender")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.lineplot(data=tips,x="total_bill",y="tip")
plt.show()

# %%
sns.histplot(data=tips,x="total_bill",kde=True,hue="gender")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.barplot(data=tips,x="day",y="tip",hue="gender")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.violinplot(data=tips,x="day",y="tip")
plt.show()

# %%
sns.jointplot(data=tips,x="total_bill",y="tip",kind="reg")
plt.show()

# %%
sns.countplot(data=tips,x="day",hue="gender")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.pairplot(data= tips,hue="day")

# %%
sns.scatterplot(data=tips,x="total_bill",y="tip")
plt.show()

# %%
sns.lineplot(data=tips,x="total_bill",y="tip")
plt.show()

# %%
sns.histplot(data=tips,x="total_bill",kde=True,hue="gender")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.barplot(data=tips,x="day",y="total_bill",hue="gender")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=tips,y="tip",hue="gender")
# Out:
# <Axes: ylabel='tip'>

# %%
sns.jointplot(data=tips,x="tip",y="total_bill",kind="reg")

# %%
sns.countplot(data=tips,x="day",hue="gender")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.pairplot(data=tips,hue="day")

# %%
sns.jointplot(data=tips,x="total_bill",y="tip",kind="reg")

# %%
sns.lineplot(data=tips,x="total_bill",y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips,x="total_bill",y="tip")
plt.title("Sactter Plot")
plt.show()

# %%
sns.barplot(data=tips,x="day",y="total_bill",hue="gender")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.histplot(data=tips,x="tip",hue="gender")
plt.show()

# %%
sns.jointplot(data=tips,x="tip",y="day")

# %%
sns.countplot(data=tips,x="day",hue="smoker")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.pairplot(data=tips,hue="gender")

# %%
sns.lineplot(data=tips,x="total_bill",y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips,x="total_bill",y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.barplot(data=tips,x="day",y="total_bill",hue="gender")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.histplot(data=tips,x="tip",hue="gender")
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.violinplot(data=tips,x="day",y="tip")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.jointplot(data=tips,x="tip",y="total_bill",kind="reg")

# %%
sns.countplot(data=tips,x="day")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.boxplot(data=tips,y="tip")
# Out:
# <Axes: ylabel='tip'>

# %%
sns.lineplot(tips,x="total_bill",y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(tips,x="total_bill",y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.barplot(tips,x="day",y="total_bill")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.histplot(tips,x="total_bill",kde=True,hue="gender")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.boxplot(tips,y="total_bill")
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.countplot(tips,x="day",hue="gender")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.jointplot(tips,x="total_bill")

# %%
sns.lineplot(tips,x="total_bill",y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.barplot(tips,x="day",y="total_bill",hue="gender")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.scatterplot(tips,x="total_bill",y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.boxplot(tips,y="tip")
# Out:
# <Axes: ylabel='tip'>

# %%
sns.jointplot(tips,x="total_bill",y="tip",kind="reg")

# %%
sns.countplot(tips,x="day",hue="gender")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.lineplot(tips,x="total_bill",y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(tips,x="total_bill",y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.barplot(tips,x="day",y="total_bill", hue="gender")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.histplot(tips,x="total_bill",hue="gender")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.boxplot(tips,y="tip")
# Out:
# <Axes: ylabel='tip'>

# %%
sns.heatmap (data=tips,annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 sns.heatmap (data=tips,annot=True)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
# ...

# %%
sns.jointplot(tips,x="total_bill",y="tip", hue="gender")

# %%
sns.countplot(tips,x="day")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.pairplot
