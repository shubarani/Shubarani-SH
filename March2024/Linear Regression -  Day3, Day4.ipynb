# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
area= np.array([350,430,455,557,640,700,770,860,900])
price= np.array([11,22,41,38,57,74,70,79,88])

# %%
area
# Out:
# array([350, 430, 455, 557, 640, 700, 770, 860, 900])

# %%
plt.figure(figsize=(10,3))
plt.xlabel("Area in Squarefeet")
plt.ylabel("Price in lakhs")
plt.title("Area vs Price plot")
plt.scatter(area, price)
plt.show()

# %%
area_mean=area.mean()
price_mean=price.mean()
area_mean, price_mean
# Out:
# (629.1111111111111, 53.333333333333336)

# %%
coef=np.sum((area-area_mean)*(price-price_mean))/np.sum(np.square(area-area_mean))

# %%
coef
# Out:
# 0.13282388809365295

# %%
intercept=price_mean-area_mean*coef
intercept
# Out:
# -30.227650487362546

# %%
#y=mx+c
y_pred=coef*area+intercept
y_pred
# Out:
# array([16.26071035, 26.88662139, 30.2072186 , 43.75525518, 54.77963789,
#        62.74907118, 72.04674334, 84.00089327, 89.3138488 ])

# %%
plt.figure(figsize=(10,3))
plt.xlabel("Area in Squarefeet")
plt.ylabel("Price in lakhs")
plt.title("Area vs Price plot")
plt.scatter(area, price)
plt.plot(area, price)
plt.scatter(area, y_pred)
plt.plot(area, y_pred)
plt.show()

# %%
MSE=np.sum(np.square(price-y_pred))/len(price)
MSE
# Out:
# 40.39988137494229

# %%
MAE=np.sum(np.abs(price-y_pred))/len(price)
MAE
# Out:
# 5.392016074217918

# %%
SSE= np.sum(np.square(price-y_pred))
SSE
# Out:
# 363.5989323744806

# %%
area=np.array([350,430,455,557,640,700,770,860,900])
price=np.array([11,22,41,38,57,74,70,79,88])

# %%
area_mean=np.mean(area)
area_mean
# Out:
# 629.1111111111111

# %%
price_mean=np.mean(price)
price_mean
# Out:
# 53.333333333333336

# %%
plt.scatter(area,price)
plt.title("Area vs Price")
plt.xlabel("Area in square feet")
plt.ylabel("Price in lakhs")
plt.show()

# %%
coef=np.sum((area-area_mean)*(price-price_mean))/np.sum(np.square(area-area_mean))

# %%
coef
# Out:
# 0.13282388809365295

# %%
intercept=price_mean-area_mean*coef

# %%
intercept
# Out:
# -30.227650487362546

# %%
y_prid = coef*area+intercept
y_prid
# Out:
# array([16.26071035, 26.88662139, 30.2072186 , 43.75525518, 54.77963789,
#        62.74907118, 72.04674334, 84.00089327, 89.3138488 ])

# %%
MSE=np.sum(np.square(price-y_prid))/len(price)

# %%
MSE
# Out:
# 40.39988137494229

# %%
MAE=np.sum(np.abs(price-y_prid))/len(price)
MAE
# Out:
# 5.392016074217918

# %%
SSE=np.sum(np.square(price-y_prid))
SSE
# Out:
# 363.5989323744806

# %%
plt.scatter(area,y_prid)
plt.plot(area,y_prid)
plt.scatter(area,price)
plt.plot(area,price)
plt.title("Area vs Price")
plt.xlabel("Area in square feet")
plt.ylabel("Price in lakhs")
plt.show()

# %%
np.round(y_prid, decimals=2)
# Out:
# array([16.26, 26.89, 30.21, 43.76, 54.78, 62.75, 72.05, 84.  , 89.31])

# %%
R2=1-(np.sum(np.square(price-y_prid))/(np.sum(np.square(price-price_mean))))

# %%
R2
# Out:
# 0.9366552382622856

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv(r"C:\Users\Shuba\Downloads\Salary_dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %%
X=df.drop("Salary",axis=1)

# %%
y=df["Salary"]

# %%
X
# Out:
#     YearsExperience
# 0               1.2
# 1               1.4
# 2               1.6
# 3               2.1
# 4               2.3
# 5               3.0
# 6               3.1
# 7               3.3
# 8               3.3
# 9               3.8
# 10              4.0
# 11              4.1
# 12              4.1
# 13              4.2
# 14              4.6
# 15              5.0
# 16              5.2
# 17              5.4
# 18              6.0
# 19              6.1
# 20              6.9
# 21              7.2
# 22              8.0
# 23              8.3
# 24              8.8
# 25              9.1
# 26              9.6
# 27              9.7
# 28             10.4
# 29             10.6

# %%
y
# Out:
# 0      39344.0
# 1      46206.0
# 2      37732.0
# 3      43526.0
# 4      39892.0
# 5      56643.0
# 6      60151.0
# 7      54446.0
# 8      64446.0
# 9      57190.0
# 10     63219.0
# 11     55795.0
# 12     56958.0
# 13     57082.0
# 14     61112.0
# 15     67939.0
# 16     66030.0
# 17     83089.0
# 18     81364.0
# 19     93941.0
# 20     91739.0
# 21     98274.0
# 22    101303.0
# 23    113813.0
# 24    109432.0
# 25    105583.0
# 26    116970.0
# 27    112636.0
# 28    122392.0
# 29    121873.0
# Name: Salary, dtype: float64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=45)

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict([[4.5]])
# Out:
# C:\Users\Shuba\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([68509.44364579])

# %%
y_pred=model.predict(X_test)

# %%
import

# %%
df=pd.read_excel(r"C:\Users\Shuba\Downloads\Linear Regression - 5 rows - hands on.xlsx")

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9434008332786764

# %%
df.head()
# Out:
#      X    y
# 0  0.5  1.3
# 1  1.0  2.2
# 2  1.5  3.1
# 3  2.0  4.0
# 4  2.5  4.9

# %%
plt.scatter(X,y)
plt.show()

# %%
X=df.drop("y",axis=1)

# %%
y=df["y"]

# %%
X
# Out:
#      X
# 0  0.5
# 1  1.0
# 2  1.5
# 3  2.0
# 4  2.5

# %%
y
# Out:
# 0    1.3
# 1    2.2
# 2    3.1
# 3    4.0
# 4    4.9
# Name: y, dtype: float64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=45)

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
model.predict([[3]])
# Out:
# C:\Users\Shuba\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([5.8])

# %%
r2_score(y_test,y_pred)
# Out:
# 1.0
